# %% [markdown]
# # TMDB Movie Data Analysis

# %%
# Importing the necessary Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mat                  
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')
print("Imported the required packages")
# Out:
# Imported the required packages

# %%
# read the given data

movie_data = pd.read_csv('DS1_C8_V3_ND_Sprint2_Data Analysis Using Python_Dataset.csv')
movie_data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### Task 1
#
# #### Load the dataset in the python notebook display the number of the rows and columns in the dataset. display the titles and genres of the first 50 movies from the dataset

# %%
# Check the no. of rows and columns

movie_data.shape
# Out:
# (4803, 20)

# %%
# Display titles and genres of the first 50 movies

first_50_movies = movie_data.head(50)[['title', 'genres']]

# Display the result

first_50_movies
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# ### Task 2
#
# #### Identify the columns that have null values and perform the null values treatment (Choose the imputation method based on the type of data in the columns of interest  )

# %%
# Without Imputation
movie_data.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
null_value = movie_data.columns[movie_data.isnull().any()]
null_value

# Display columns with null values null_columns
movie_data.fillna(0, inplace=True)

# %%
# After Imputation
movie_data.isnull().sum()
# Out:
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 0
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# ### Task 3
#
# #### To display the movie categories that have  a budget greater than dollar 220000 in python for movie dataset

# %%
# Filter categories with a budget greater than $220,000
budget = movie_data[movie_data['budget'] > 2200000][['genres', 'budget']]

print("Filtered Movie Data:")
budget
# Out:
# Filtered Movie Data:
#                                                  genres     budget
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  237000000
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...  300000000
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  245000000
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...  250000000
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  260000000
# ...                                                 ...        ...
# 4586  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   35000000
# 4596                     [{"id": 27, "name": "Horror"}]    6000000
# 4682                     [{"id": 27, "name": "Horror"}]   13000000
# 4720                      [{"id": 18, "name": "Drama"}]    8500000
# 4758  [{"id": 53, "name": "Thriller"}, {"id": 878, "...    4000000
#
# [3386 rows x 2 columns]

# %% [markdown]
# ### Task 4
#
# #### Display the movie categories where the revenu is greater than dollar 961000000

# %%
# Filter where the budget is greater than $961,000,000
revenue = movie_data[movie_data['revenue'] > 961000000]

# Display the categories with a budget greater than $961,000,000
revenue
# Out:
#         budget                                             genres  \
# 0    237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 7    280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 12   200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16   220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17   380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 25   200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26   250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 28   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 31   200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 32   200000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 36   210000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# ...

# %% [markdown]
# ### Task 5
# #### In the dataset, there are some movies for which the budget and revenue columns have the value 0 which means unknown values. Remove the rows with the values 0 from both the budget and revenue columns.

# %%
# Display the number of rows before removing
print(f"Number of rows before removing: {len(movie_data)}")

# Remove rows where both 'Budget' and 'Revenue' are 0
movie_data = movie_data[(movie_data['budget'] != 0) & (movie_data['revenue'] != 0)]

# Display the number of rows after removing
print(f"Number of rows after removing: {len(movie_data)}")

# Now, movie_data contains only rows where both 'Budget' and 'Revenue' are not 0
# Out:
# Number of rows before removing: 4803
# Number of rows after removing: 3229

# %% [markdown]
# ### Task 6
#
# #### List the top 10 movies with the highest revenues and the top 10 movies wit the least budget.

# %%
# Top 10 movies with the highest revenues

top_10_revenue = movie_data.nlargest(10, 'revenue')
print("Top 10 movies with the highest revenues:")
print(top_10_revenue[['title', 'revenue']])

# Top 10 movies with the least budget
top_10_least_budget = movie_data.nsmallest(10, 'budget')
print("\nTop 10 movies with the least budget:")
print(top_10_least_budget[['title', 'budget']])
# Out:
# Top 10 movies with the highest revenues:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 124                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 546                     Minions  1156730962
# 26   Captain America: Civil War  1153304495
#
# Top 10 movies with the least budget:
#                    title  budget
# 4238        Modern Times       1
# 3611  A Farewell to Arms       4
# 3372        Split Second       7
# 3419        Bran Nue Dae       7
# 4608        The Prophecy       8
# 3131   Of Horses and Men      10
# 3137           Nurse 3-D      10
# 2933            F.I.S.T.      11
# 1912      Angela's Ashes      25
# 1771      The 51st State      28

# %% [markdown]
# ### Task 7
#
# #### How are popularities of movies related with the movie budgets? Are they correlated or totally uncorrelated with each other? write the interpretation of your analysis.

# %%
# Calculate the correlation between popularity and budget
correlation = movie_data['popularity'].corr(movie_data['budget'])

# Display the correlation coefficient
print(f"Correlation between popularity and budget: {correlation}")
# Out:
# Correlation between popularity and budget: 0.4319901360079751

# %%
# Calculate the correlation matrix
correlation_matrix = movie_data[['popularity', 'budget']].corr()

# Create a heatmap
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Set plot title
plt.title('Correlation Heatmap: Popularity vs Budget')

# Show the plot
plt.show()

# %% [markdown]
# ### Interpretation:
#
# #### If the correlation coefficient is close to 1, it suggests a strong positive correlation, meaning as the movie budget increases, the popularity tends to increase.
# #### If the correlation coefficient is close to -1, it suggests a strong negative correlation, meaning as the movie budget increases, the popularity tends to decrease.
# #### If the correlation coefficient is close to 0, it suggests a weak or no correlation, meaning there is no clear linear relationship between movie budgets and popularity.
# #### Keep in mind that correlation does not imply causation, and other factors could influence the relationship between movie budgets and popularity. It's always good to complement statistical analysis with domain knowledge and other forms of exploration

# %% [markdown]
# ### Task 8
#
# #### Identify and display the names of all production companies along with the no. of times they appear in the dataset.

# %%
# Display the names of all production companies along with their counts
production_comp_counts = movie_data['production_companies'].value_counts()
print("Production companies and their counts:")
production_comp_counts
# Out:
# Production companies and their counts:
# [{"name": "Paramount Pictures", "id": 4}]                                                                                                                                                             48
# []                                                                                                                                                                                                    41
# [{"name": "Universal Pictures", "id": 33}]                                                                                                                                                            35
# [{"name": "New Line Cinema", "id": 12}]                                                                                                                                                               29
# ...

# %% [markdown]
# ### Task 9
#
# #### Display the names of top 25 production comapnies based on the no. of movies they have produced in the descending order of the no. of movies produced.

# %%
# Count the occurrences of each production company
production_company_counts = movie_data['production_companies'].value_counts()

# Display the top 25 production companies
top_25_production_companies = production_company_counts.head(25)

# Display the result
print("Top 25 Production Companies based on the Number of Movies Produced:")
print(top_25_production_companies)
# Out:
# Top 25 Production Companies based on the Number of Movies Produced:
# [{"name": "Paramount Pictures", "id": 4}]                                                                           48
# []                                                                                                                  41
# [{"name": "Universal Pictures", "id": 33}]                                                                          35
# [{"name": "New Line Cinema", "id": 12}]                                                                             29
# [{"name": "Columbia Pictures", "id": 5}]                                                                            28
# [{"name": "Twentieth Century Fox Film Corporation", "id": 306}]                                                     25
# [{"name": "Warner Bros.", "id": 6194}]                                                                              24
# ...

# %% [markdown]
# ### Task 10
#
# #### Sort the data in descending order based on revenue and filter the top 500 movies. Find measures of central tendency for the following columns using the filter data.
# #### budget, revenue and runtime
#
# #### perform outerlier analysis for above 3 col. using box plot chart.

# %%
# Sort the data in descending order based on revenue
movie_data_sorted = movie_data.sort_values(by='revenue', ascending=False)

# Filter the top 500 movies
top_500_movies = movie_data_sorted.head(500)

# Display measures of central tendency for 'budget', 'revenue', and 'runtime'
measures_of_central_tendency = top_500_movies[['budget', 'revenue', 'runtime']].describe()
print("Measures of central tendency for budget, revenue, and runtime:")
print(measures_of_central_tendency)

# Outlier analysis using box plot
plt.figure(figsize=(12, 6))

# Box plot for 'budget'
plt.subplot(1, 3, 1)
sb.boxplot(y=top_500_movies['budget'])
plt.title('Budget')

# Box plot for 'revenue'
plt.subplot(1, 3, 2)
sb.boxplot(y=top_500_movies['revenue'])
plt.title('Revenue')

# Box plot for 'runtime'
plt.subplot(1, 3, 3)
sb.boxplot(y=top_500_movies['runtime'])
plt.title('Runtime')

plt.tight_layout()
plt.show()
# Out:
# Measures of central tendency for budget, revenue, and runtime:
#              budget       revenue     runtime
# count  5.000000e+02  5.000000e+02  500.000000
# mean   1.031937e+08  4.585776e+08  118.720000
# std    6.224893e+07  2.685357e+08   23.257158
# min    6.000000e+04  2.177643e+08   70.000000
# 25%    5.500000e+07  2.814473e+08  100.000000
# 50%    9.500000e+07  3.630016e+08  116.000000
# 75%    1.500000e+08  5.471332e+08  132.000000
# max    3.800000e+08  2.787965e+09  238.000000

# %% [markdown]
# ### Task 11
#
# #### Identify and display the names of the movies along with their runtimes for those movies that have above average runtime using the data from the previous task.

# %%
# Assuming 'top_500_movies' is the DataFrame from the previous task

# Calculate the average runtime
average_runtime = top_500_movies['runtime'].mean()

# Filter movies with above-average runtime
above_average_runtime_movies = top_500_movies[top_500_movies['runtime'] > average_runtime]

# Display names of movies along with their runtimes
movie_names_runtimes = above_average_runtime_movies[['title', 'runtime']]
print("Movies with above-average runtime:")
movie_names_runtimes
# Out:
# Movies with above-average runtime:
#                  title  runtime
# 0               Avatar    162.0
# 25             Titanic    194.0
# 16        The Avengers    143.0
# 28      Jurassic World    124.0
# 44           Furious 7    137.0
# ...                ...      ...
# 521       The Terminal    128.0
# 397   It's Complicated    121.0
# 1744        Knocked Up    129.0
# 717       Jack Reacher    130.0
# 714         Collateral    120.0
#
# [234 rows x 2 columns]
